# %%
from parsetrees.expr_parser import webwork_parser
from parsetrees.expr_parser import Eval_parsed
reload(Eval_parsed)
import pickle
from collections import deque
from collections import defaultdict
import cluster_functions
reload(cluster_functions)
from itertools import combinations
from datetime import datetime as dt

# %%
### Load Week3 data ###
data = pickle.load(open('../2016data/Week4_data.pkl','rb'))
data_timestamp = pickle.load(open('../2016data/Week4_correct_timestamp.pkl','rb'))

# %%
data.keys()
# Out:
# [('9', '2'),
#  ('2', '2'),
#  ('8', '3'),
#  ('7', '2'),
#  ('2', '7'),
#  ('3', '4'),
#  ('1', '2'),
#  ('9', '5'),
#  ('2', '3'),
#  ('5', '4'),
#  ('4', '3'),
#  ('9', '1'),
#  ('7', '1'),
#  ('3', '3'),
#  ('5', '3'),
#  ('9', '4'),
#  ('4', '2'),
#  ('8', '1'),
#  ('1', '1'),
#  ('6', '1'),
#  ('3', '2'),
#  ('5', '2'),
#  ('2', '5'),
#  ('4', '1'),
#  ('6', '2'),
#  ('9', '3'),
#  ('2', '1'),
#  ('8', '2'),
#  ('3', '1'),
#  ('7', '3'),
#  ('9', '6'),
#  ('2', '6'),
#  ('2', '4'),
#  ('1', '3'),
#  ('5', '1')]

# %%
data[('1','2')]
# Out:
# [{'answer': '(0.3 + 0.2 - (0.38))/0.2',
#   'attempt': u'0.3+0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 21:40:23',
#   'user_id': 'rjanowit',
#   'var': []},
#  {'answer': '(0.5 + 0.3 - (0.65))/0.3',
#   'attempt': u'0.65',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 21:41:00',
#   'user_id': 'rjanowit',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.46))/0.1',
#   'attempt': u'0.4*0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 21:42:08',
#   'user_id': 'rjanowit',
#   'var': []},
#  {'answer': '(0.1 + 0.5 - (0.55))/0.5',
#   'attempt': u'0.1+0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 21:51:26',
#   'user_id': 'rjanowit',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.38))/0.3',
#   'attempt': u'P(A|B)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 21:54:12',
#   'user_id': 'rjanowit',
#   'var': []},
#  {'answer': '(0.4 + 0.4 - (0.48))/0.4',
#   'attempt': u'0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 21:54:59',
#   'user_id': 'rjanowit',
#   'var': []},
#  {'answer': '(0.5 + 0.3 - (0.65))/0.3',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 21:55:33',
#   'user_id': 'rjanowit',
#   'var': []},
#  {'answer': '(0.2 + 0.1 - (0.28))/0.1',
#   'attempt': u'.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:46:31',
#   'user_id': 'Lpascual',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.42))/0.1',
#   'attempt': u'.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:47:05',
#   'user_id': 'Lpascual',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.38))/0.3',
#   'attempt': u'.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:47:43',
#   'user_id': 'Lpascual',
#   'var': []},
#  {'answer': '(0.1 + 0.2 - (0.26))/0.2',
#   'attempt': u'2.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:49:37',
#   'user_id': 'Lpascual',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.51))/0.3',
#   'attempt': u'0',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:50:38',
#   'user_id': 'Lpascual',
#   'var': []},
#  {'answer': '(0.4 + 0.5 - (0.5))/0.5',
#   'attempt': u'P(A)P(B)/P(B)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:53:19',
#   'user_id': 'Lpascual',
#   'var': []},
#  {'answer': '(0.5 + 0.5 - (0.5))/0.5',
#   'attempt': u'.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:57:34',
#   'user_id': 'Lpascual',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.38))/0.3',
#   'attempt': u'(0.2*0.3)/0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 05:01:24',
#   'user_id': 'Lpascual',
#   'var': []},
#  {'answer': '(0.1 + 0.3 - (0.34))/0.3',
#   'attempt': u'.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 05:08:30',
#   'user_id': 'Lpascual',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.44))/0.3',
#   'attempt': u'0.06/0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:33:17',
#   'user_id': 'yazin-yousif',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.44))/0.3',
#   'attempt': u'0.06/0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:33:44',
#   'user_id': 'yazin-yousif',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.46))/0.1',
#   'attempt': u'.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 23:35:19',
#   'user_id': 'abtom',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.44))/0.3',
#   'attempt': u'.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 05:16:39',
#   'user_id': 'abtom',
#   'var': []},
#  {'answer': '(0.3 + 0.5 - (0.5))/0.5',
#   'attempt': u'.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 05:17:04',
#   'user_id': 'abtom',
#   'var': []},
#  {'answer': '(0.5 + 0.2 - (0.6))/0.2',
#   'attempt': u'.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 05:17:44',
#   'user_id': 'abtom',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.5))/0.1',
#   'attempt': u'1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'mvkrishn',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.5))/0.1',
#   'attempt': u'1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'mvkrishn',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.5))/0.1',
#   'attempt': u'1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 21:23:47',
#   'user_id': 'mvkrishn',
#   'var': []},
#  {'answer': '(0.3 + 0.1 - (0.37))/0.1',
#   'attempt': u'3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:19:32',
#   'user_id': 'adejesus',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.42))/0.4',
#   'attempt': u'(0.1*0.4)/(0.4)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:20:06',
#   'user_id': 'adejesus',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.5))/0.1',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:22:15',
#   'user_id': 'adejesus',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.5))/0.1',
#   'attempt': u'((0.5) * (0.1)) / (0.1)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:26:25',
#   'user_id': 'adejesus',
#   'var': []},
#  {'answer': '(0.3 + 0.5 - (0.65))/0.5',
#   'attempt': u'(0.3 + 0.5) / 0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:28:49',
#   'user_id': 'adejesus',
#   'var': []},
#  {'answer': '(0.4 + 0.5 - (0.7))/0.5',
#   'attempt': u'(.2 * ((.5 * .4)/(.4))) / 0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:52:00',
#   'user_id': 'adejesus',
#   'var': []},
#  {'answer': '(0.4 + 0.2 - (0.52))/0.2',
#   'attempt': u'(0.4 * 0.2) / 0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:53:43',
#   'user_id': 'adejesus',
#   'var': []},
#  {'answer': '(0.4 + 0.2 - (0.44))/0.2',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 08:07:44',
#   'user_id': 'aliceh',
#   'var': []},
#  {'answer': '(0.1 + 0.2 - (0.26))/0.2',
#   'attempt': u'.04/.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 03:53:19',
#   'user_id': 'NicoleStone',
#   'var': []},
#  {'answer': '(0.2 + 0.4 - (0.52))/0.4',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 22:00:20',
#   'user_id': 'Khang_Vinh',
#   'var': []},
#  {'answer': '(0.3 + 0.1 - (0.37))/0.1',
#   'attempt': u'0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 04:13:49',
#   'user_id': 'pyae',
#   'var': []},
#  {'answer': '(0.1 + 0.2 - (0.26))/0.2',
#   'attempt': u'0.26',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:49:39',
#   'user_id': 'Jisu',
#   'var': []},
#  {'answer': '(0.2 + 0.4 - (0.52))/0.4',
#   'attempt': u'(0.2+0.4)-0.52',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:51:17',
#   'user_id': 'Jisu',
#   'var': []},
#  {'answer': '(0.4 + 0.3 - (0.46))/0.3',
#   'attempt': u'0.46-0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:52:08',
#   'user_id': 'Jisu',
#   'var': []},
#  {'answer': '(0.4 + 0.3 - (0.58))/0.3',
#   'attempt': u'0.58-0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:52:55',
#   'user_id': 'Jisu',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.38))/0.3',
#   'attempt': u'0.38-((0.2+0.3)-0.38)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:54:37',
#   'user_id': 'Jisu',
#   'var': []},
#  {'answer': '(0.3 + 0.5 - (0.5))/0.5',
#   'attempt': u'(0.5-(0.5-0.3))',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:57:00',
#   'user_id': 'Jisu',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.19))/0.1',
#   'attempt': u'.1(.1)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:58:22',
#   'user_id': 'Jisu',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.38))/0.3',
#   'attempt': u'0.38-((0.2+0.3)-0.38)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:59:34',
#   'user_id': 'Jisu',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.19))/0.1',
#   'attempt': u'((0.1+0.1)-0.19)/0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 05:03:31',
#   'user_id': 'Jisu',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'((0.3+0.2)-0.44)/0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 05:03:55',
#   'user_id': 'Jisu',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.51))/0.3',
#   'attempt': u'((0.3+0.3)-0.51)/0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 05:04:18',
#   'user_id': 'Jisu',
#   'var': []},
#  {'answer': '(0.2 + 0.4 - (0.52))/0.4',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 07:41:29',
#   'user_id': 'ray003',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.42))/0.4',
#   'attempt': u'0.1*0.4 / (0.4)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 07:32:12',
#   'user_id': 'ReneSanchez',
#   'var': []},
#  {'answer': '(0.2 + 0.4 - (0.52))/0.4',
#   'attempt': u'( 0.2 + 0.4 - 0.52 )/ 0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 07:33:49',
#   'user_id': 'ReneSanchez',
#   'var': []},
#  {'answer': '(0.5 + 0.5 - (0.5))/0.5',
#   'attempt': u'( 0.5 + 0.5 - 0.5 )/ 0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 07:34:57',
#   'user_id': 'ReneSanchez',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.7))/0.4',
#   'attempt': u' 0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'kyle',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.7))/0.4',
#   'attempt': u' 0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'kyle',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.7))/0.4',
#   'attempt': u' 0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 20:51:14',
#   'user_id': 'kyle',
#   'var': []},
#  {'answer': '(0.2 + 0.4 - (0.52))/0.4',
#   'attempt': u'.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 22:00:21',
#   'user_id': 'tommyt1109',
#   'var': []},
#  {'answer': '(0.5 + 0.3 - (0.5))/0.3',
#   'attempt': u'P(A)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 01:48:12',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.5 + 0.5 - (0.75))/0.5',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 01:48:41',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.1 + 0.3 - (0.37))/0.3',
#   'attempt': u'0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 01:50:29',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.3 + 0.5 - (0.5))/0.5',
#   'attempt': u'0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 01:50:55',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.2 + 0.5 - (0.5))/0.5',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 01:51:36',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.2 + 0.1 - (0.26))/0.1',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 01:52:26',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.38))/0.2',
#   'attempt': u'P(A)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 01:52:53',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.2 + 0.4 - (0.44))/0.4',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 01:53:35',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.5 + 0.2 - (0.6))/0.2',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 02:02:26',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.4 + 0.4 - (0.48))/0.4',
#   'attempt': u'0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 02:02:54',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.1 + 0.2 - (0.26))/0.2',
#   'attempt': u'0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 02:08:46',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.55))/0.1',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 02:11:19',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.1 + 0.2 - (0.26))/0.2',
#   'attempt': u'0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 02:12:00',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.5 + 0.5 - (0.75))/0.5',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 02:12:23',
#   'user_id': 'ThucPhan',
#   'var': []},
#  {'answer': '(0.1 + 0.2 - (0.26))/0.2',
#   'attempt': u'0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:39:55',
#   'user_id': 'christhoperbernard',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.7))/0.4',
#   'attempt': u'1/2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:41:43',
#   'user_id': 'christhoperbernard',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.51))/0.3',
#   'attempt': u'0.09/0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:42:07',
#   'user_id': 'christhoperbernard',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.42))/0.1',
#   'attempt': u'.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 11:02:04',
#   'user_id': 'alvinyho',
#   'var': []},
#  {'answer': '(0.2 + 0.5 - (0.6))/0.5',
#   'attempt': u'(.2*.5)/.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 11:08:37',
#   'user_id': 'alvinyho',
#   'var': []},
#  {'answer': '(0.3 + 0.1 - (0.34))/0.1',
#   'attempt': u'(.3*.1)/.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 11:12:42',
#   'user_id': 'alvinyho',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 11:13:12',
#   'user_id': 'alvinyho',
#   'var': []},
#  {'answer': '(0.4 + 0.3 - (0.58))/0.3',
#   'attempt': u'.12/(.3)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:34:39',
#   'user_id': 'alvinyho',
#   'var': []},
#  {'answer': '(0.2 + 0.5 - (0.6))/0.5',
#   'attempt': u'0',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:39:55',
#   'user_id': 'alvinyho',
#   'var': []},
#  {'answer': '(0.5 + 0.3 - (0.5))/0.3',
#   'attempt': u'.15/.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:41:51',
#   'user_id': 'alvinyho',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.46))/0.4',
#   'attempt': u'P(A)*P(B)/P(B)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:43:12',
#   'user_id': 'alvinyho',
#   'var': []},
#  {'answer': '(0.4 + 0.3 - (0.46))/0.3',
#   'attempt': u'.4*.3/.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:43:37',
#   'user_id': 'alvinyho',
#   'var': []},
#  {'answer': '(0.3 + 0.1 - (0.37))/0.1',
#   'attempt': u'.3*.1/.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:44:06',
#   'user_id': 'alvinyho',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.44))/0.3',
#   'attempt': u'0.06',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 02:03:39',
#   'user_id': 'SothyrakSrey',
#   'var': []},
#  {'answer': '(0.1 + 0.3 - (0.37))/0.3',
#   'attempt': u'0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 02:04:43',
#   'user_id': 'SothyrakSrey',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.18))/0.1',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 06:27:40',
#   'user_id': 'shuang',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'0.44',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 03:59:17',
#   'user_id': 'Von',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.38))/0.3',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 04:03:33',
#   'user_id': 'Von',
#   'var': []},
#  {'answer': '(0.2 + 0.1 - (0.26))/0.1',
#   'attempt': u'(0.2*0.1)/0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 05:18:59',
#   'user_id': 'Von',
#   'var': []},
#  {'answer': '(0.5 + 0.3 - (0.5))/0.3',
#   'attempt': u'(0.5 * 0.3) / 0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 05:22:34',
#   'user_id': 'Von',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.5))/0.4',
#   'attempt': u'0.5/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 05:24:13',
#   'user_id': 'Von',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.7))/0.4',
#   'attempt': u'(0.5*0.4)/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 09:21:00',
#   'user_id': 'Von',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.42))/0.1',
#   'attempt': u'.8',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 01:25:35',
#   'user_id': 'lmfink',
#   'var': []},
#  {'answer': '(0.5 + 0.3 - (0.5))/0.3',
#   'attempt': u'1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 01:26:13',
#   'user_id': 'lmfink',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.19))/0.1',
#   'attempt': u'.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 07:07:00',
#   'user_id': 'MattBowen96',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.18))/0.1',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 16:25:15',
#   'user_id': 'chenboy3',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.42))/0.3',
#   'attempt': u'0.6',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 16:25:38',
#   'user_id': 'chenboy3',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.38))/0.3',
#   'attempt': u'(0.3+0.2-0.38)/0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 19:48:38',
#   'user_id': 'sunilraiyani',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.42))/0.3',
#   'attempt': u'0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:47:34',
#   'user_id': 'aliqbal',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.42))/0.3',
#   'attempt': u'P(A)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 06:53:08',
#   'user_id': 'aliqbal',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.51))/0.3',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 06:53:30',
#   'user_id': 'aliqbal',
#   'var': []},
#  {'answer': '(0.5 + 0.2 - (0.6))/0.2',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 06:55:01',
#   'user_id': 'aliqbal',
#   'var': []},
#  {'answer': '(0.5 + 0.2 - (0.6))/0.2',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 06:55:25',
#   'user_id': 'aliqbal',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.19))/0.1',
#   'attempt': u'0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 06:58:29',
#   'user_id': 'aliqbal',
#   'var': []},
#  {'answer': '(0.1 + 0.2 - (0.28))/0.2',
#   'attempt': u'(0.1 + 0.2 - 0.28)/0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 01:13:39',
#   'user_id': 'cpence',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.18))/0.1',
#   'attempt': u'(0.1*0.1)/0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 01:29:42',
#   'user_id': 'PriyankaK',
#   'var': []},
#  {'answer': '(0.1 + 0.5 - (0.55))/0.5',
#   'attempt': u'(0.1+0.5-0.55)/0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 01:34:04',
#   'user_id': 'PriyankaK',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.51))/0.3',
#   'attempt': u'(0.3+0.3-0.51)/0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 01:34:42',
#   'user_id': 'PriyankaK',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.5))/0.4',
#   'attempt': u'0.4/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'twsalim',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.5))/0.4',
#   'attempt': u'0.4/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'twsalim',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.5))/0.4',
#   'attempt': u'0.4/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 07:04:21',
#   'user_id': 'twsalim',
#   'var': []},
#  {'answer': '(0.1 + 0.3 - (0.34))/0.3',
#   'attempt': u'0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 05:39:19',
#   'user_id': 'Riyang',
#   'var': []},
#  {'answer': '(0.2 + 0.5 - (0.6))/0.5',
#   'attempt': u'(0.5-0.6+0.2)/0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 05:41:20',
#   'user_id': 'Riyang',
#   'var': []},
#  {'answer': '(0.4 + 0.4 - (0.48))/0.4',
#   'attempt': u'(0.4+0.4-0.48)/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 05:44:12',
#   'user_id': 'Riyang',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.44))/0.3',
#   'attempt': u'0.8',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 10:44:04',
#   'user_id': 'woguan',
#   'var': []},
#  {'answer': '(0.1 + 0.2 - (0.26))/0.2',
#   'attempt': u'0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 10:55:36',
#   'user_id': 'woguan',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.46))/0.1',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 10:59:22',
#   'user_id': 'woguan',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 11:03:05',
#   'user_id': 'woguan',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.5))/0.4',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 11:03:35',
#   'user_id': 'woguan',
#   'var': []},
#  {'answer': '(0.1 + 0.5 - (0.55))/0.5',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 11:04:01',
#   'user_id': 'woguan',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.55))/0.1',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 11:05:29',
#   'user_id': 'woguan',
#   'var': []},
#  {'answer': '(0.2 + 0.1 - (0.28))/0.1',
#   'attempt': u'(0.2+0.1-0.28)/0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 16:37:49',
#   'user_id': 'TianhaoQiu',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.55))/0.1',
#   'attempt': u'(0.5+0.1-0.55)/0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 16:39:16',
#   'user_id': 'TianhaoQiu',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.38))/0.2',
#   'attempt': u'0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 03:05:48',
#   'user_id': 'Byung',
#   'var': []},
#  {'answer': '(0.2 + 0.5 - (0.6))/0.5',
#   'attempt': u'0.1/0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 03:11:10',
#   'user_id': 'Byung',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.7))/0.4',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 20:50:26',
#   'user_id': 'YuqinWu',
#   'var': []},
#  {'answer': '(0.4 + 0.4 - (0.64))/0.4',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 07:40:34',
#   'user_id': 'JonahCruz',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'(0.3*0.2)/0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 00:28:34',
#   'user_id': 'JonahCruz',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 00:30:10',
#   'user_id': 'JonahCruz',
#   'var': []},
#  {'answer': '(0.1 + 0.2 - (0.26))/0.2',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 00:30:33',
#   'user_id': 'JonahCruz',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.51))/0.3',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 00:34:23',
#   'user_id': 'JonahCruz',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 00:34:45',
#   'user_id': 'JonahCruz',
#   'var': []},
#  {'answer': '(0.3 + 0.5 - (0.5))/0.5',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 00:35:12',
#   'user_id': 'JonahCruz',
#   'var': []},
#  {'answer': '(0.3 + 0.1 - (0.34))/0.1',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 00:35:34',
#   'user_id': 'JonahCruz',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'(0.3*0.2)/0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 00:39:15',
#   'user_id': 'JonahCruz',
#   'var': []},
#  {'answer': '(0.3 + 0.5 - (0.5))/0.5',
#   'attempt': u'.8',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:49:23',
#   'user_id': 'hunguyen',
#   'var': []},
#  {'answer': '(0.4 + 0.3 - (0.58))/0.3',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:49:55',
#   'user_id': 'hunguyen',
#   'var': []},
#  {'answer': '(0.2 + 0.1 - (0.28))/0.1',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:50:20',
#   'user_id': 'hunguyen',
#   'var': []},
#  {'answer': '(0.4 + 0.4 - (0.48))/0.4',
#   'attempt': u'.8',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:51:55',
#   'user_id': 'hunguyen',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.18))/0.1',
#   'attempt': u'.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 04:53:19',
#   'user_id': 'hunguyen',
#   'var': []},
#  {'answer': '(0.2 + 0.1 - (0.28))/0.1',
#   'attempt': u'(.02)/.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 19:52:52',
#   'user_id': 'codyndoan',
#   'var': []},
#  {'answer': '(0.4 + 0.2 - (0.52))/0.2',
#   'attempt': u'(.52)/.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 19:59:07',
#   'user_id': 'codyndoan',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.44))/0.3',
#   'attempt': u'((.2 + .3) - .44)/.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 19:59:57',
#   'user_id': 'codyndoan',
#   'var': []},
#  {'answer': '(0.1 + 0.5 - (0.55))/0.5',
#   'attempt': u'0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 03:12:24',
#   'user_id': 'AndrewYang24',
#   'var': []},
#  {'answer': '(0.4 + 0.5 - (0.7))/0.5',
#   'attempt': u'.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 22:33:16',
#   'user_id': 'ankannan',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.42))/0.4',
#   'attempt': u'.08/.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 22:57:53',
#   'user_id': 'ankannan',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.42))/0.4',
#   'attempt': u'0.25',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 17:39:29',
#   'user_id': 'QIQIWU',
#   'var': []},
#  {'answer': '(0.4 + 0.3 - (0.46))/0.3',
#   'attempt': u'(.24/.3)/.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 17:40:52',
#   'user_id': 'QIQIWU',
#   'var': []},
#  {'answer': '(0.2 + 0.4 - (0.52))/0.4',
#   'attempt': u'0.08/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 17:41:45',
#   'user_id': 'QIQIWU',
#   'var': []},
#  {'answer': '(0.5 + 0.2 - (0.6))/0.2',
#   'attempt': u'.1/.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 17:42:13',
#   'user_id': 'QIQIWU',
#   'var': []},
#  {'answer': '(0.2 + 0.1 - (0.26))/0.1',
#   'attempt': u'.04/.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 17:42:53',
#   'user_id': 'QIQIWU',
#   'var': []},
#  {'answer': '(0.2 + 0.5 - (0.5))/0.5',
#   'attempt': u'0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 21:03:54',
#   'user_id': 'alebedev',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 23:59:30',
#   'user_id': 'SidneyNguyen',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.42))/0.4',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 22:29:04',
#   'user_id': 'CharlesCruz',
#   'var': []},
#  {'answer': '(0.3 + 0.1 - (0.34))/0.1',
#   'attempt': u'(1 - 0.34)/(0.3)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 06:03:54',
#   'user_id': 'Ryan_Yi',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.5))/0.1',
#   'attempt': u'(0.1)/(0.1)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 06:29:39',
#   'user_id': 'Ryan_Yi',
#   'var': []},
#  {'answer': '(0.3 + 0.5 - (0.5))/0.5',
#   'attempt': u'(0.3+0.5-0.5)/(0.5)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 06:30:38',
#   'user_id': 'Ryan_Yi',
#   'var': []},
#  {'answer': '(0.4 + 0.2 - (0.52))/0.2',
#   'attempt': u'(1-0.52)/0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:03:30',
#   'user_id': 't2xu',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.42))/0.3',
#   'attempt': u'(0.3*0.3)/0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:03:56',
#   'user_id': 't2xu',
#   'var': []},
#  {'answer': '(0.5 + 0.5 - (0.5))/0.5',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:04:46',
#   'user_id': 't2xu',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.46))/0.1',
#   'attempt': u'(1-.046)/0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:06:36',
#   'user_id': 't2xu',
#   'var': []},
#  {'answer': '(0.3 + 0.5 - (0.5))/0.5',
#   'attempt': u'(0.5*0.3)/0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:09:13',
#   'user_id': 't2xu',
#   'var': []},
#  {'answer': '(0.1 + 0.3 - (0.34))/0.3',
#   'attempt': u'.04/.03',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 21:28:57',
#   'user_id': 't2xu',
#   'var': []},
#  {'answer': '(0.3 + 0.5 - (0.65))/0.5',
#   'attempt': u'(.3+.5-.65)/.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 21:29:48',
#   'user_id': 't2xu',
#   'var': []},
#  {'answer': '(0.2 + 0.4 - (0.44))/0.4',
#   'attempt': u'(.2+.4-.44)/.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 21:30:16',
#   'user_id': 't2xu',
#   'var': []},
#  {'answer': '(0.3 + 0.5 - (0.5))/0.5',
#   'attempt': u'(.3+.5-.5)/.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 21:30:40',
#   'user_id': 't2xu',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.46))/0.4',
#   'attempt': u'(.1+.4-.46)/.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 21:31:12',
#   'user_id': 't2xu',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.46))/0.1',
#   'attempt': u'(.4+.1-.46)/.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 21:31:41',
#   'user_id': 't2xu',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.38))/0.3',
#   'attempt': u'(.3+.2-.38)/.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 21:32:13',
#   'user_id': 't2xu',
#   'var': []},
#  {'answer': '(0.5 + 0.2 - (0.6))/0.2',
#   'attempt': u'(.5+.2-.6)/.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 21:32:40',
#   'user_id': 't2xu',
#   'var': []},
#  {'answer': '(0.5 + 0.3 - (0.65))/0.3',
#   'attempt': u'(0.5) + (0.3) - (0.65)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:53:04',
#   'user_id': 'karl-rummler',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.5))/0.1',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:53:31',
#   'user_id': 'karl-rummler',
#   'var': []},
#  {'answer': '(0.2 + 0.5 - (0.5))/0.5',
#   'attempt': u'1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 05:56:50',
#   'user_id': 'migil',
#   'var': []},
#  {'answer': '(0.5 + 0.2 - (0.6))/0.2',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 05:58:20',
#   'user_id': 'migil',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.42))/0.4',
#   'attempt': u'0.08/0.42',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 01:19:13',
#   'user_id': 'brandon_vo',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.46))/0.1',
#   'attempt': u'0.04/0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 01:20:11',
#   'user_id': 'brandon_vo',
#   'var': []},
#  {'answer': '(0.1 + 0.5 - (0.5))/0.5',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 06:54:58',
#   'user_id': 'VanessaC',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.38))/0.2',
#   'attempt': u'(0.5-0.38)/0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 00:26:21',
#   'user_id': 'evahuynh',
#   'var': []},
#  {'answer': '(0.2 + 0.1 - (0.26))/0.1',
#   'attempt': u'0.04 / 0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 01:27:36',
#   'user_id': 'aives',
#   'var': []},
#  {'answer': '(0.5 + 0.5 - (0.75))/0.5',
#   'attempt': u'0.25',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 11:16:19',
#   'user_id': 'gtran',
#   'var': []},
#  {'answer': '(0.1 + 0.3 - (0.37))/0.3',
#   'attempt': u'0.3 / 0.3 ',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 02:31:47',
#   'user_id': 'PaulWall43',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.5))/0.1',
#   'attempt': u'(0.5 * 0.1) / 0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 02:33:37',
#   'user_id': 'PaulWall43',
#   'var': []},
#  {'answer': '(0.2 + 0.2 - (0.36))/0.2',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 02:34:00',
#   'user_id': 'PaulWall43',
#   'var': []},
#  {'answer': '(0.3 + 0.4 - (0.58))/0.4',
#   'attempt': u'(.7 - 0.58)/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 02:55:24',
#   'user_id': 'PaulWall43',
#   'var': []},
#  {'answer': '(0.4 + 0.4 - (0.64))/0.4',
#   'attempt': u'(0.8 - 0.64)/ 0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 02:58:01',
#   'user_id': 'PaulWall43',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.46))/0.1',
#   'attempt': u'(0.4*0.1)/(0.4)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 18:59:21',
#   'user_id': 'Joonhan',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.42))/0.4',
#   'attempt': u'(0.1*0.4)/(0.4)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 18:59:57',
#   'user_id': 'Joonhan',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.19))/0.1',
#   'attempt': u'0.01/0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:03:06',
#   'user_id': 'Joonhan',
#   'var': []},
#  {'answer': '(0.5 + 0.2 - (0.6))/0.2',
#   'attempt': u'0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 03:09:19',
#   'user_id': 'yuhan',
#   'var': []},
#  {'answer': '(0.4 + 0.5 - (0.7))/0.5',
#   'attempt': u'0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 03:09:41',
#   'user_id': 'yuhan',
#   'var': []},
#  {'answer': '(0.1 + 0.5 - (0.5))/0.5',
#   'attempt': u'0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 03:10:58',
#   'user_id': 'yuhan',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.18))/0.1',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 03:12:49',
#   'user_id': 'yuhan',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 03:13:39',
#   'user_id': 'yuhan',
#   'var': []},
#  {'answer': '(0.4 + 0.5 - (0.5))/0.5',
#   'attempt': u'0.8',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 03:14:13',
#   'user_id': 'yuhan',
#   'var': []},
#  {'answer': '(0.2 + 0.4 - (0.52))/0.4',
#   'attempt': u'.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 01:40:49',
#   'user_id': 'aspindle',
#   'var': []},
#  {'answer': '(0.4 + 0.5 - (0.7))/0.5',
#   'attempt': u'0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 06:45:32',
#   'user_id': 'CheyennePayne',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.55))/0.1',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 18:38:32',
#   'user_id': 'Zeyi',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.7))/0.4',
#   'attempt': u'.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 22:57:58',
#   'user_id': 'KevinKlein',
#   'var': []},
#  {'answer': '(0.2 + 0.1 - (0.28))/0.1',
#   'attempt': u'.02/.28',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 01:59:16',
#   'user_id': 'KevinKlein',
#   'var': []},
#  {'answer': '(0.4 + 0.4 - (0.48))/0.4',
#   'attempt': u'.32/.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 02:03:23',
#   'user_id': 'KevinKlein',
#   'var': []},
#  {'answer': '(0.4 + 0.5 - (0.5))/0.5',
#   'attempt': u'.4/.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 02:04:14',
#   'user_id': 'KevinKlein',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.5))/0.4',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 20:40:12',
#   'user_id': 'Melvinw',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.46))/0.1',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 20:48:59',
#   'user_id': 'Melvinw',
#   'var': []},
#  {'answer': '(0.5 + 0.3 - (0.65))/0.3',
#   'attempt': u'(0.5*0.3)/0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 06:23:05',
#   'user_id': 'Melvinw',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.5))/0.4',
#   'attempt': u'1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 17:49:46',
#   'user_id': 'JiangfengYin',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.42))/0.4',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'ryanguyen',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.42))/0.4',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'ryanguyen',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.42))/0.4',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 02:18:19',
#   'user_id': 'ryanguyen',
#   'var': []},
#  {'answer': '(0.2 + 0.5 - (0.5))/0.5',
#   'attempt': u'.1/.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'njcrow',
#   'var': []},
#  {'answer': '(0.2 + 0.5 - (0.5))/0.5',
#   'attempt': u'.1/.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'njcrow',
#   'var': []},
#  {'answer': '(0.2 + 0.5 - (0.5))/0.5',
#   'attempt': u'.1/.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 06:59:00',
#   'user_id': 'njcrow',
#   'var': []},
#  {'answer': '(0.2 + 0.5 - (0.6))/0.5',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 23:18:02',
#   'user_id': 'njcrow',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.55))/0.1',
#   'attempt': u'.55/.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 23:18:02',
#   'user_id': 'njcrow',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.55))/0.1',
#   'attempt': u'.55/.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 23:18:02',
#   'user_id': 'njcrow',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.55))/0.1',
#   'attempt': u'.55/.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 23:19:45',
#   'user_id': 'njcrow',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.38))/0.2',
#   'attempt': u'.38/.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 23:20:08',
#   'user_id': 'njcrow',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.42))/0.3',
#   'attempt': u'(.3*.3)/.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 23:20:08',
#   'user_id': 'njcrow',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.42))/0.3',
#   'attempt': u'(.3*.3)/.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 23:20:08',
#   'user_id': 'njcrow',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.42))/0.3',
#   'attempt': u'(.3*.3)/.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 23:21:22',
#   'user_id': 'njcrow',
#   'var': []},
#  {'answer': '(0.1 + 0.5 - (0.55))/0.5',
#   'attempt': u'(.1*.5)/.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 23:21:59',
#   'user_id': 'njcrow',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.44))/0.3',
#   'attempt': u'0.06',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 02:57:58',
#   'user_id': 'dillonliu',
#   'var': []},
#  {'answer': '(0.1 + 0.2 - (0.26))/0.2',
#   'attempt': u'0.06/0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
# ...
#   'attempt': u'(0.4*0.3)/0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 08:41:32',
#   'user_id': 'kmesic',
#   'var': []},
#  {'answer': '(0.2 + 0.2 - (0.36))/0.2',
#   'attempt': u'(((0.2) + (0.2))-0.36)/0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 08:44:11',
#   'user_id': 'kmesic',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.42))/0.1',
#   'attempt': u'.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'HansGamboa',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.42))/0.1',
#   'attempt': u'.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'HansGamboa',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.42))/0.1',
#   'attempt': u'.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 20:52:13',
#   'user_id': 'HansGamboa',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 21:19:04',
#   'user_id': 'HansGamboa',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.46))/0.1',
#   'attempt': u'0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 21:21:30',
#   'user_id': 'HansGamboa',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'((0.3+0.2) - 0.44)/0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:20:36',
#   'user_id': 'bfalk',
#   'var': []},
#  {'answer': '(0.5 + 0.2 - (0.5))/0.2',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:41:48',
#   'user_id': 'bfalk',
#   'var': []},
#  {'answer': '(0.5 + 0.3 - (0.65))/0.3',
#   'attempt': u'((0.5 + 0.3) - 0.65)/0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:44:34',
#   'user_id': 'bfalk',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.7))/0.4',
#   'attempt': u'.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 07:05:45',
#   'user_id': 'NickWong',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.51))/0.3',
#   'attempt': u'.6',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 07:07:45',
#   'user_id': 'NickWong',
#   'var': []},
#  {'answer': '(0.3 + 0.4 - (0.46))/0.4',
#   'attempt': u'P(A)+P(B)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 07:08:40',
#   'user_id': 'NickWong',
#   'var': []},
#  {'answer': '(0.1 + 0.5 - (0.5))/0.5',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 07:09:42',
#   'user_id': 'NickWong',
#   'var': []},
#  {'answer': '(0.5 + 0.5 - (0.5))/0.5',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 07:10:06',
#   'user_id': 'NickWong',
#   'var': []},
#  {'answer': '(0.2 + 0.1 - (0.26))/0.1',
#   'attempt': u'.26',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 07:10:32',
#   'user_id': 'NickWong',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 07:12:17',
#   'user_id': 'NickWong',
#   'var': []},
#  {'answer': '(0.5 + 0.5 - (0.5))/0.5',
#   'attempt': u'1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 07:14:03',
#   'user_id': 'NickWong',
#   'var': []},
#  {'answer': '(0.3 + 0.3 - (0.51))/0.3',
#   'attempt': u'0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 00:27:05',
#   'user_id': 'JoshuaKomala',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.46))/0.4',
#   'attempt': u'(0.1*0.4)/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 20:44:22',
#   'user_id': 'kballew00',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.42))/0.4',
#   'attempt': u'(0.1*0.4)/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 20:46:40',
#   'user_id': 'kballew00',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.18))/0.1',
#   'attempt': u'(0.1*0.1)/0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 20:57:01',
#   'user_id': 'kballew00',
#   'var': []},
#  {'answer': '(0.2 + 0.1 - (0.28))/0.1',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 20:57:33',
#   'user_id': 'kballew00',
#   'var': []},
#  {'answer': '(0.1 + 0.5 - (0.5))/0.5',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 20:58:37',
#   'user_id': 'kballew00',
#   'var': []},
#  {'answer': '(0.5 + 0.5 - (0.5))/0.5',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 20:59:47',
#   'user_id': 'kballew00',
#   'var': []},
#  {'answer': '(0.5 + 0.5 - (0.5))/0.5',
#   'attempt': u'1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 16:29:59',
#   'user_id': 'kballew00',
#   'var': []},
#  {'answer': '(0.1 + 0.2 - (0.26))/0.2',
#   'attempt': u'.74/.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 04:05:05',
#   'user_id': 'Alix',
#   'var': []},
#  {'answer': '(0.5 + 0.5 - (0.5))/0.5',
#   'attempt': u'.5/.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 04:07:45',
#   'user_id': 'Alix',
#   'var': []},
#  {'answer': '(0.1 + 0.3 - (0.34))/0.3',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 04:08:08',
#   'user_id': 'Alix',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.44))/0.3',
#   'attempt': u'.06/.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 04:18:30',
#   'user_id': 'Alix',
#   'var': []},
#  {'answer': '(0.2 + 0.2 - (0.32))/0.2',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:37:12',
#   'user_id': 'Yangc',
#   'var': []},
#  {'answer': '(0.2 + 0.5 - (0.5))/0.5',
#   'attempt': u'(0.5-(0.2+0.5))/0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:38:31',
#   'user_id': 'Yangc',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.38))/0.3',
#   'attempt': u'0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 06:32:54',
#   'user_id': 'KevinChrisayrton',
#   'var': []},
#  {'answer': '(0.3 + 0.4 - (0.46))/0.4',
#   'attempt': u'0.7',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 06:34:06',
#   'user_id': 'KevinChrisayrton',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.19))/0.1',
#   'attempt': u'0',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 06:34:29',
#   'user_id': 'KevinChrisayrton',
#   'var': []},
#  {'answer': '(0.2 + 0.3 - (0.44))/0.3',
#   'attempt': u'0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 06:35:20',
#   'user_id': 'KevinChrisayrton',
#   'var': []},
#  {'answer': '(0.1 + 0.3 - (0.37))/0.3',
#   'attempt': u'0.03',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 06:37:01',
#   'user_id': 'KevinChrisayrton',
#   'var': []},
#  {'answer': '(0.2 + 0.1 - (0.28))/0.1',
#   'attempt': u'0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 06:37:47',
#   'user_id': 'KevinChrisayrton',
#   'var': []},
#  {'answer': '(0.4 + 0.5 - (0.5))/0.5',
#   'attempt': u'0.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 06:38:10',
#   'user_id': 'KevinChrisayrton',
#   'var': []},
#  {'answer': '(0.5 + 0.2 - (0.5))/0.2',
#   'attempt': u'1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 06:39:46',
#   'user_id': 'KevinChrisayrton',
#   'var': []},
#  {'answer': '(0.1 + 0.5 - (0.5))/0.5',
#   'attempt': u'0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 02:53:00',
#   'user_id': 'thartopu',
#   'var': []},
#  {'answer': '(0.4 + 0.5 - (0.5))/0.5',
#   'attempt': u'0.8',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 02:53:54',
#   'user_id': 'thartopu',
#   'var': []},
#  {'answer': '(0.4 + 0.4 - (0.64))/0.4',
#   'attempt': u'0.16/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 18:14:10',
#   'user_id': 'maxcjx',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.7))/0.4',
#   'attempt': u'0.2/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 18:14:51',
#   'user_id': 'maxcjx',
#   'var': []},
#  {'answer': '(0.5 + 0.3 - (0.65))/0.3',
#   'attempt': u'.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 23:39:14',
#   'user_id': 'PizzaPolice',
#   'var': []},
#  {'answer': '(0.3 + 0.1 - (0.34))/0.1',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'kirkkw',
#   'var': []},
#  {'answer': '(0.3 + 0.1 - (0.34))/0.1',
#   'attempt': u'0.03/0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'kirkkw',
#   'var': []},
#  {'answer': '(0.3 + 0.1 - (0.34))/0.1',
#   'attempt': u'0.03/0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': 'null',
#   'set_id': 'Week4',
#   'timestamp': 'null',
#   'user_id': 'kirkkw',
#   'var': []},
#  {'answer': '(0.3 + 0.1 - (0.34))/0.1',
#   'attempt': u'0.03/0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 08:57:46',
#   'user_id': 'kirkkw',
#   'var': []},
#  {'answer': '(0.4 + 0.4 - (0.64))/0.4',
#   'attempt': u'.16/.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 09:02:22',
#   'user_id': 'kirkkw',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.55))/0.1',
#   'attempt': u'.05/.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 09:03:25',
#   'user_id': 'kirkkw',
#   'var': []},
#  {'answer': '(0.3 + 0.1 - (0.37))/0.1',
#   'attempt': u'.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 00:06:49',
#   'user_id': 'rleaton',
#   'var': []},
#  {'answer': '(0.3 + 0.2 - (0.44))/0.2',
#   'attempt': u'0.06/0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 05:24:05',
#   'user_id': 'HaoDong',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.42))/0.4',
#   'attempt': u'0.08/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-16 05:24:49',
#   'user_id': 'HaoDong',
#   'var': []},
#  {'answer': '(0.2 + 0.1 - (0.26))/0.1',
#   'attempt': u'0',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 20:23:21',
#   'user_id': 'g5park',
#   'var': []},
#  {'answer': '(0.4 + 0.4 - (0.64))/0.4',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 20:33:27',
#   'user_id': 'g5park',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.42))/0.4',
#   'attempt': u'0.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 23:58:42',
#   'user_id': 'bhaveshnibber',
#   'var': []},
#  {'answer': '(0.2 + 0.5 - (0.5))/0.5',
#   'attempt': u'',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 18:12:18',
#   'user_id': 'KabirGogia',
#   'var': []},
#  {'answer': '(0.5 + 0.4 - (0.7))/0.4',
#   'attempt': u'0.2/0.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 22:21:46',
#   'user_id': 'malloryishaya',
#   'var': []},
#  {'answer': '(0.2 + 0.2 - (0.36))/0.2',
#   'attempt': u'.36',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:39:11',
#   'user_id': 'Sync',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.18))/0.1',
#   'attempt': u'.02/.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:45:17',
#   'user_id': 'Sync',
#   'var': []},
#  {'answer': '(0.4 + 0.1 - (0.42))/0.1',
#   'attempt': u'.08/.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 19:46:25',
#   'user_id': 'Sync',
#   'var': []},
#  {'answer': '(0.4 + 0.2 - (0.44))/0.2',
#   'attempt': u'.12/.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 04:08:09',
#   'user_id': 'djku',
#   'var': []},
#  {'answer': '(0.4 + 0.5 - (0.5))/0.5',
#   'attempt': u'((P(A) + P(B)) - P(A U B))/P(B)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 04:09:24',
#   'user_id': 'djku',
#   'var': []},
#  {'answer': '(0.5 + 0.5 - (0.75))/0.5',
#   'attempt': u'(P(A)*P(B))/P(B)',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 04:10:21',
#   'user_id': 'djku',
#   'var': []},
#  {'answer': '(0.4 + 0.5 - (0.7))/0.5',
#   'attempt': u'.2/.5',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 04:16:15',
#   'user_id': 'djku',
#   'var': []},
#  {'answer': '(0.1 + 0.4 - (0.46))/0.4',
#   'attempt': u'.04/.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 04:18:06',
#   'user_id': 'djku',
#   'var': []},
#  {'answer': '(0.3 + 0.4 - (0.58))/0.4',
#   'attempt': u'.12/.4',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 04:18:45',
#   'user_id': 'djku',
#   'var': []},
#  {'answer': '(0.4 + 0.3 - (0.58))/0.3',
#   'attempt': u'.7 - .58',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 19:15:16',
#   'user_id': 'sokunev',
#   'var': []},
#  {'answer': '(0.5 + 0.1 - (0.55))/0.1',
#   'attempt': u'(.6 -.55)/.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 19:26:55',
#   'user_id': 'sokunev',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.18))/0.1',
#   'attempt': u'.2',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 18:53:40',
#   'user_id': 'Aidan',
#   'var': []},
#  {'answer': '(0.1 + 0.1 - (0.18))/0.1',
#   'attempt': u'0.02/0.1',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 20:23:10',
#   'user_id': 'anMihaly',
#   'var': []},
#  {'answer': '(0.3 + 0.1 - (0.37))/0.1',
#   'attempt': u'0.3',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '1',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-17 00:09:27',
#   'user_id': 'DarrenYang',
#   'var': []},
#  {'answer': '(0.5 + 0.2 - (0.6))/0.2',
#   'attempt': u'23',
#   'part_id': '2',
#   'problem_id': '1',
#   'score': '0',
#   'set_id': 'Week4',
#   'timestamp': u'2016-10-18 06:41:41',
#   'user_id': 'kim',
#   'var': []}]

# %%
pro_par_count = defaultdict(int)
pro_count = defaultdict(int)
total_count = 0
for k in data:
    pro_par_count[k] = len(data[k])
    pro_par_count[k[0]] += len(data[k])
    total_count += len(data[k])
total_count
# Out:
# 24735

# %%
pro_par_count
# Out:
# defaultdict(int,
#             {'1': 1222,
#              '10': 4179,
#              '11': 2970,
#              '12': 1445,
#              '13': 1142,
#              '2': 7469,
#              '3': 1204,
#              '4': 234,
#              '5': 266,
#              '6': 1716,
#              '7': 200,
#              '8': 1020,
#              '9': 1668,
#              ('1', '1'): 611,
#              ('1', '2'): 611,
#              ('10', '1'): 597,
#              ('10', '2'): 597,
#              ('10', '3'): 597,
#              ('10', '4'): 597,
#              ('10', '5'): 597,
#              ('10', '6'): 597,
#              ('10', '7'): 597,
#              ('11', '1'): 425,
#              ('11', '2'): 425,
#              ('11', '3'): 425,
#              ('11', '4'): 425,
#              ('11', '5'): 425,
#              ('11', '6'): 425,
#              ('11', '7'): 420,
#              ('12', '1'): 290,
#              ('12', '2'): 290,
#              ('12', '3'): 290,
#              ('12', '4'): 290,
#              ('12', '5'): 285,
#              ('13', '1'): 165,
#              ('13', '2'): 165,
#              ('13', '3'): 165,
#              ('13', '4'): 165,
#              ('13', '5'): 165,
#              ('13', '6'): 165,
#              ('13', '7'): 152,
#              ('2', '1'): 1067,
#              ('2', '2'): 1067,
#              ('2', '3'): 1067,
#              ('2', '4'): 1067,
#              ('2', '5'): 1067,
#              ('2', '6'): 1067,
#              ('2', '7'): 1067,
#              ('3', '1'): 301,
#              ('3', '2'): 301,
#              ('3', '3'): 301,
#              ('3', '4'): 301,
#              ('4', '1'): 234,
#              ('5', '1'): 266,
#              ('6', '1'): 572,
#              ('6', '2'): 572,
#              ('6', '3'): 572,
#              ('7', '1'): 200,
#              ('8', '1'): 340,
#              ('8', '2'): 340,
#              ('8', '3'): 340,
#              ('9', '1'): 556,
#              ('9', '2'): 556,
#              ('9', '3'): 556})

# %%
### Make params as inputs to function find_matches ###
Week = 'Week4'
problem_id = '1'
params = defaultdict(list)
for (pro, par) in data.keys():
    if (pro == problem_id):
        m = cluster_functions.make_params(pro, par, data)
        params[par] = [m]
# Out:
# 4 Error in parser P(A|B), LEXER: Illegal character '|' at location 3
# parse_tree empty
# 12 Error in parser P(A)P(B)/P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 32 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 55 Error in parser P(A), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 61 Error in parser P(A), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 75 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 79 Error in parser P(A)*P(B)/P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 98 Error in parser P(A), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 99 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 115 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 117 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 118 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 125 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 127 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 128 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 129 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 130 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 131 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 132 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 135 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 136 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 158 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 181 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 200 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 201 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 204 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 205 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 210 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 225 Error in parser P(A), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 231 Error in parser 0..6, LEXER: Illegal character '.' at location 1
# parse_tree empty
# 246 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 253 eval_tree empty
# 256 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 262 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 263 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 264 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 309 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 312 Error in parser P(A)*P(B)/P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 314 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 321 Error in parser P(A)*P(B)- P(A and B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 327 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 328 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 353 Error in parser P(A)+P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 354 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 355 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 363 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 364 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 369 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 371 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 386 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 398 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 404 Error in parser ((P(A) + P(B)) - P(A U B))/P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,5)',location=5
# parse_tree empty
# 405 Error in parser (P(A)*P(B))/P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,4)',location=4
# parse_tree empty
# 12 Error in parser P(A)P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 55 Error in parser P(A)P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 61 Error in parser P(A)P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 75 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 79 Error in parser P(A)*P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 97 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 98 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 101 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 117 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 126 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 127 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 128 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 129 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 130 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 131 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 132 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 136 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 181 Error in parser P(A)P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 188 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 214 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 262 Error in parser P(A)*P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 312 Error in parser P(A)*P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 321 Error in parser P(A)*P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 353 Error in parser P(A)P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 354 Error in parser P(A)*P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 365 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 371 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 404 Error in parser (P(A) + P(B)) - P(A U B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,4)',location=4
# parse_tree empty
# 405 Error in parser P(A)*P(B), yacc:Syntax error at 'LexToken(RPAREN,u')',1,3)',location=3
# parse_tree empty
# 32 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 91 Error in parser no, LEXER: Illegal character 'n' at location 0
# parse_tree empty
# 94 Error in parser No, LEXER: Illegal character 'N' at location 0
# parse_tree empty
# 104 Error in parser no, LEXER: Illegal character 'n' at location 0
# parse_tree empty
# 115 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 117 Error in parser no, LEXER: Illegal character 'n' at location 0
# parse_tree empty
# 125 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 126 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 181 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 188 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 201 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 204 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 205 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 210 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 214 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 246 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 256 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 262 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 263 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 264 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 278 Error in parser no, LEXER: Illegal character 'n' at location 0
# parse_tree empty
# 309 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 314 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 321 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 327 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 328 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 331 Error in parser yes, LEXER: Illegal character 'y' at location 0
# parse_tree empty
# 340 Error in parser no, LEXER: Illegal character 'n' at location 0
# parse_tree empty
# 354 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 355 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 363 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 364 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 365 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 369 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 386 Error in parser , yacc:Syntax error - Empty token
# parse_tree empty
# 414

# %%
for p in params.keys():
    print p, ': ', len(params[p])
# Out:
# 1 :  1
# 3 :  1
# 2 :  1

# %%
### Create clusters, if no hits, clustered as 'Nothing' ###
problem_clusters={}
for part in params:
    problem_clusters[part]=defaultdict(list)
    for p in params[part]:
        if len(p['att_tree']) > 1:
            if p['att_tree'][0] == 'X':
                att = p['att_tree'][1]
            else:
                att = p['att_tree'][0][1]
            if p['ans_tree'][0] == 'X':
                ans = p['ans_tree'][1]
            else:
                ans = p['ans_tree'][0][1]
            try:
                att*ans
            except:
                print p['attempt']
            if att * ans < 0:
                problem_clusters[part]['Wrong_Sign'] += [(p['answer'], p['attempt'])]
                continue
            elif float(ans).is_integer() and not float(att).is_integer():
                problem_clusters[part]['Fraction'] += [(p['answer'], p['attempt'])]
                continue
        final_pairs = cluster_functions.find_matches(p)
        if len(final_pairs)>0:
            sorted_final = sorted(final_pairs,key=lambda x: x[0])
            sorted_node = [s[0] for s in sorted_final]
            problem_clusters[part][str(sorted_node)] += [(p['answer'], p['attempt'], sorted_final)]
        else:
            if p['attempt'].isdigit() or len(p['att_tree']) == 1:
                problem_clusters[part]['Digits'] += [(p['answer'], p['attempt'])]
            else:
                problem_clusters[part]['Nothing'] += [(p['answer'], p['attempt'], p['att_tree'], p['user_id'], p['user_var'], p['timestamp'])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-5ba16af7044d> in <module>()
#       4     problem_clusters[part]=defaultdict(list)
#       5     for p in params[part]:
# ----> 6         if len(p['att_tree']) > 1:
#       7             if p['att_tree'][0] == 'X':
#       8                 att = p['att_tree'][1]
#
# TypeError: list indices must be integers, not str

# %%
problem_clusters.keys()
# Out:
# [u'1', u'3', u'2', u'5', u'4']

# %%
part_id = '2'
problem_clusters[part_id].keys()
# Out:
# ['Nothing', 'Digits', 'Wrong_Sign', 'Fraction']

# %%
from datetime import datetime as dt
from datetime import timedelta as td
problem_clusters[part_id]['redirect'] = []
problem_clusters[part_id]['no_match_cluster'] = {}
dependency_list = [i for i in ['1']]
user_id = ''
for n in problem_clusters[part_id]['Nothing']:
    time = dt.strptime(n[-1], "%Y-%m-%d %H:%M:%S")
    # part 3 depends on part 1 and 2
    # we create one signature 'redirect'
    # that the hints should redirect students to previous parts
    if part_id == '1' and user_id != n[3]:
        user_id = n[3]
        ini_time_str = n[-1]
    if part_id != '1':
        user_id = n[3]
        ini_time_str = data_timestamp[user_id][(problem_id, '1')][1]
    ini_time = dt.strptime(ini_time_str, "%Y-%m-%d %H:%M:%S")
    
    dependency_timestamp = [dt.strptime(data_timestamp[user_id][(problem_id, d)][1], "%Y-%m-%d %H:%M:%S") for d in dependency_list]
    if any(time < t for t in dependency_timestamp):
        problem_clusters[part_id]['redirect'].append(n)
    else:
        if not user_id in problem_clusters[part_id]['no_match_cluster']:
            no_match_cluster = problem_clusters[part_id]['no_match_cluster'][user_id] = {'first_attemp':ini_time_str}
            for d in dependency_list+[part_id]:
                if data_timestamp[user_id][(problem_id, d)]:
                    correct_attempt = data_timestamp[user_id][(problem_id, d)][0]
                    t = dt.strptime(data_timestamp[user_id][(problem_id, d)][1], "%Y-%m-%d %H:%M:%S")
                    key = 'part' + str(d) + '_correct_attempt'
                    no_match_cluster[key] = [str(t-ini_time), correct_attempt]
            t = dt.strptime(n[-1], "%Y-%m-%d %H:%M:%S")
            no_match_cluster['part'+str(part_id)+'_incorrect_attempt'] = [(str(t-ini_time), n[1])]
        else:
            t = dt.strptime(n[-1], "%Y-%m-%d %H:%M:%S")
            no_match_cluster['part'+str(part_id)+'_incorrect_attempt'] += [(str(t-ini_time), n[1])]
for user in no_match_cluster:
    last_att_time = no_match_cluster['part'+str(part_id)+'_incorrect_attempt'][-1][0]
    if 'day' not in last_att_time:
        t = dt.strptime(last_att_time, "%H:%M:%S")
        time_diff = td(hours=t.hour, minutes=t.minute, seconds=t.second)
        if time_diff.total_seconds() < 60 * 3:
            print no_match_cluster[user]
            no_match_clusters.pop(user)

# %%
problem_clusters[part_id]['no_match_cluster']
# Out:
# {u'a8ho': {'first_attemp': u'2015-10-07 05:50:21',
#   'part1_correct_attempt': ['0:00:17', u'26^3'],
#   'part1_incorrect_attempt': [('0:00:00', u'3^26')]},
#  u'abjara': {'first_attemp': u'2015-10-05 23:04:49',
#   'part1_correct_attempt': ['0:00:41', u'26^5'],
#   'part1_incorrect_attempt': [('0:00:00', u'5^26'), ('0:00:00', u'6^26')]},
#  u'ajabasa': {'first_attemp': u'2015-10-05 21:32:45',
#   'part1_correct_attempt': ['0:01:33', u'26^4'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/22!')]},
#  u'ajvanega': {'first_attemp': u'2015-10-02 22:53:31',
#   'part1_correct_attempt': ['5 days, 0:49:38', u'26^6'],
#   'part1_incorrect_attempt': [('0:00:00', u'(26*25*24*23*22*21)')]},
#  u'any027': {'first_attemp': u'2015-10-03 11:09:25',
#   'part1_correct_attempt': ['0:00:22', u'26^6'],
#   'part1_incorrect_attempt': [('0:00:00', u'(26! / (6! * (20!)) )')]},
#  u'aportuga': {'first_attemp': u'2015-10-06 05:43:16',
#   'part1_correct_attempt': ['0:51:59', u'26^5'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/5!'),
#    ('0:01:26', u'26!/(26-5)!')]},
#  u'awollner': {'first_attemp': u'2015-10-06 15:45:29',
#   'part1_correct_attempt': ['0:02:42', u'26^6'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/20!')]},
#  u'ccn001': {'first_attemp': u'2015-10-06 06:28:27',
#   'part1_correct_attempt': ['0:03:43', u'26^5'],
#   'part1_incorrect_attempt': [('0:00:00', u'(26!)/(5!)(26-5)!'),
#    ('0:00:00', u'26!/((26-5)!5!)'),
#    ('0:02:09', u'((26-5)!/21!)')]},
#  u'cstringh': {'first_attemp': u'2015-10-04 00:13:03',
#   'part1_correct_attempt': ['0:00:18', u'26^4'],
#   'part1_incorrect_attempt': [('0:00:00', u'4^26')]},
#  u'dcastlem': {'first_attemp': u'2015-10-03 21:48:46',
#   'part1_correct_attempt': ['0:27:37', u'26^5'],
#   'part1_incorrect_attempt': [('0:00:00', u'5!')]},
#  u'dkostins': {'first_attemp': u'2015-10-05 21:16:32',
#   'part1_correct_attempt': ['4:37:06', u'26^6'],
#   'part1_incorrect_attempt': [('0:00:00', u'6!')]},
#  u'dpereira': {'first_attemp': u'2015-10-03 21:15:59',
#   'part1_correct_attempt': ['0:00:32', u'26^4'],
#   'part1_incorrect_attempt': [('0:00:00', u'26! / 22!')]},
#  u'eaherman': {'first_attemp': u'2015-10-03 21:07:10',
#   'part1_correct_attempt': ['0:00:29', u'26^4'],
#   'part1_incorrect_attempt': [('0:00:00', u'4!')]},
#  u'gsrandha': {'first_attemp': u'2015-10-02 02:08:50',
#   'part1_correct_attempt': ['0:00:17', u'26*26*26*26*26*26'],
#   'part1_incorrect_attempt': [('0:00:00', u'6*5*4*3*2')]},
#  u'hachrist': {'first_attemp': u'2015-10-04 22:44:44',
#   'part1_correct_attempt': ['0:08:13', u'26^6'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/(20!)')]},
#  u'hmnaing': {'first_attemp': u'2015-10-07 02:57:56',
#   'part1_correct_attempt': ['15:10:57', u'26^5'],
#   'part1_incorrect_attempt': [('0:00:00', u'C(26,5)*1')]},
#  u'jblynch': {'first_attemp': u'2015-10-05 04:34:38',
#   'part1_correct_attempt': ['0:03:10', u'26^5'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/21!')]},
#  u'jel075': {'first_attemp': u'2015-10-08 00:48:32',
#   'part1_correct_attempt': ['0:04:38', u'26*26*26*26'],
#   'part1_incorrect_attempt': [('0:00:00', u'(26!/(22!))/4!'),
#    ('0:00:26', u'(26!/(22!))'),
#    ('0:01:41', u'26*25*24*23')]},
#  u'jew037': {'first_attemp': u'2015-10-06 02:24:44',
#   'part1_correct_attempt': ['0:00:22', u'11881376'],
#   'part1_incorrect_attempt': [('0:00:00', u'1.49*10^18')]},
#  u'jfalcone': {'first_attemp': u'2015-10-07 03:48:13',
#   'part1_correct_attempt': ['0:01:35', u'26 * 26 * 26 * 26'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/(22!4!)')]},
#  u'kalang': {'first_attemp': u'2015-10-05 22:48:58',
#   'part1_correct_attempt': ['0:01:07', u'26^6'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/20!'),
#    ('0:00:34', u'26!/(6!*20!)')]},
#  u'kosung': {'first_attemp': u'2015-10-07 06:23:39',
#   'part1_correct_attempt': ['0:02:12', u'26^5'],
#   'part1_incorrect_attempt': [('0:00:00', u'24!/19!'),
#    ('0:01:44', u'26!/21!')]},
#  u'kquong': {'first_attemp': u'2015-10-03 21:30:17',
#   'part1_correct_attempt': ['0:00:13', u'26^6'],
#   'part1_incorrect_attempt': [('0:00:00', u'6^6')]},
#  u'ksmurlo': {'first_attemp': u'2015-10-05 22:10:46',
#   'part1_correct_attempt': ['1 day, 2:31:16', u'26*26*26*26*26'],
#   'part1_incorrect_attempt': [('0:00:00', u'26*26*26')]},
#  u'kthui': {'first_attemp': u'2015-10-04 07:35:17',
#   'part1_correct_attempt': ['0:13:40', u'26*26*26'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/3!'),
#    ('0:00:28', u'26!/(26-3)!')]},
#  u'mtrafeca': {'first_attemp': u'2015-10-02 06:10:03',
#   'part1_correct_attempt': ['0:06:46', u'26^5'],
#   'part1_incorrect_attempt': [('0:00:00', u'26*25*24*23*22')]},
#  u'muy002': {'first_attemp': u'2015-10-07 21:44:49',
#   'part1_correct_attempt': ['0:10:39', u'26^4'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/(4!*22!)'),
#    ('0:03:59', u'26*25*24*23')]},
#  u'r2fisher': {'first_attemp': u'2015-10-05 16:37:51',
#   'part1_correct_attempt': ['4:09:19', u'26^3'],
#   'part1_incorrect_attempt': [('0:00:00', u'3^26')]},
#  u'rlhagen': {'first_attemp': u'2015-10-04 22:54:32',
#   'part1_correct_attempt': ['0:01:02', u'26^4'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/(4!(26-4)!)'),
#    ('0:00:12', u'26!/((26-4)!)')]},
#  u's6deng': {'first_attemp': u'2015-10-06 21:23:09',
#   'part1_correct_attempt': ['0:00:09', u'26^5'],
#   'part1_incorrect_attempt': [('0:00:00', u'5*(26^5)')]},
#  u'sachadal': {'first_attemp': u'2015-10-05 19:05:50',
#   'part1_correct_attempt': ['0:02:24', u'26^4'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/(26-4)!')]},
#  u'sayao': {'first_attemp': u'2015-10-03 00:41:11',
#   'part1_correct_attempt': ['0:00:43', u'26^4'],
#   'part1_incorrect_attempt': [('0:00:00', u'(26*4)!/7!')]},
#  u'starinia': {'first_attemp': u'2015-10-07 01:44:03',
#   'part1_correct_attempt': ['0:01:00', u'26^4'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/(4!(22!))'),
#    ('0:00:00', u'((26*25*24*23*22*21)/(6*5*4*3*2))'),
#    ('0:01:47', u'26!/(6!(20!))'),
#    ('0:02:08', u'26!/(6!(26-6)!)'),
#    ('0:04:27', u'26!/6!'),
#    ('0:35:32', u'26!/(6!*(26-6)!)')]},
#  u'tcuddy': {'first_attemp': u'2015-10-02 20:23:28',
#   'part1_correct_attempt': ['0:00:29', u'26**5'],
#   'part1_incorrect_attempt': [('0:00:00', u'26*26*26')]},
#  u'tpmach': {'first_attemp': u'2015-10-03 22:00:48',
#   'part1_correct_attempt': ['0:01:10', u'26^6'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/(26-6)!')]},
#  u'vasharma': {'first_attemp': u'2015-10-05 06:33:05',
#   'part1_correct_attempt': ['0:12:04', u'26*26*26*26'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/(26-4)!'),
#    ('0:11:38', u'26!/4!(26-4)!'),
#    ('0:11:45', u'26!/(4!(26-4)!)')]},
#  u'vsamant': {'first_attemp': u'2015-10-02 17:18:49',
#   'part1_correct_attempt': ['0:00:45', u'26^5'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/((5!)(21!))')]},
#  u'vsosnovs': {'first_attemp': u'2015-10-04 18:07:56',
#   'part1_correct_attempt': ['0:08:24', u'26^6'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/20!')]},
#  u'whcombs': {'first_attemp': u'2015-10-07 19:49:54',
#   'part1_correct_attempt': ['0:05:15', u'26^6'],
#   'part1_incorrect_attempt': [('0:00:00', u'(26!)/(6!(26-6)!)'),
#    ('0:00:31', u'(26!)/((26-6)!)'),
#    ('0:04:03', u'(26!)/(6!(26-6)!)')]},
#  u'ytc012': {'first_attemp': u'2015-10-06 09:51:49',
#   'part1_correct_attempt': ['0:00:27', u'26^6'],
#   'part1_incorrect_attempt': [('0:00:00', u'26!/(20!6!)')]}}

# %%
problem_clusters['3']['Nothing_clusters']["[('R.0', 456976.0)]"]
# Out:
# [(u'1*26*26*26*26*26', u'gsrandha', [(u'$n2', u'6'), (u'$n2', u'6')]),
#  (u'26*26*26*26*25', u'mtrafeca', [(u'$n2', u'5'), (u'$n2', u'5')]),
#  (u'1*26*26*26*26*26', u'gsrandha', [(u'$n2', u'6'), (u'$n2', u'6')]),
#  (u'26*26*26*26*5', u'mtrafeca', [(u'$n2', u'5'), (u'$n2', u'5')]),
#  (u'26*26*26*26*25', u'mtrafeca', [(u'$n2', u'5'), (u'$n2', u'5')]),
#  (u'26*26*26*26*5', u'mtrafeca', [(u'$n2', u'5'), (u'$n2', u'5')])]

# %%
pickle.dump(problem_clusters, open('clusters/'+Week+'/'+Week+'_'+problem_id+'_cluster.pkl','wb'))

# %%
### Print some clusters ###
for c in clusters['1'].keys():
    if len(clusters['1'][c]) > 10:
        print len(clusters['1'][c]), c
# Out:
# 11 [('R.0.1.1.0', 5.0, u'11-6', u'5'), ('R.1', 2048.0, u'2^11', u'2^11')]
# 55 Nothing
# 11 [('R.0.1.1.0.0', 9.0, u'9', u'9'), ('R.0.1.1.0.1', 6.0, u'6', u'6'), ('R.1', 512.0, u'2^9', u'2^9')]
# 11 [('R.0.1.1.0.0', 10.0, u'10', u'10'), ('R.0.1.1.0.1', 6.0, u'6', u'6'), ('R.1', 1024.0, u'2^10', u'2^10')]
# 24 [('R.0.1.1.0.0', 9.0, u'9', u'9'), ('R.1', 512.0, u'2^9', u'2^9')]
# 18 [('R.1', 512.0, u'2^9', u'512')]
# 19 [('R.0.1.1.0.0', 10.0, u'10', u'10'), ('R.1', 1024.0, u'2^10', u'2^10')]
# 31 [('R.0.1.1.0.0', 11.0, u'11', u'11'), ('R.1', 2048.0, u'2^11', u'2^11')]
# 13 [('R.0.1.1.0.0', 11.0, u'11', u'11'), ('R.0.1.1.0.1', 6.0, u'6', u'6'), ('R.1', 2048.0, u'2^11', u'2^11')]
# 16 [('R.0.1.1.0.1', 6.0, u'6', u'6'), ('R.1.0', 2.0, u'2', u'2')]
# 14 [('R.1', 2048.0, u'2^11', u'2048')]

# %%
################# TESTING BELOW ################

# %%
#### Example of flatten ####
parse_tree = webwork_parser.parse_webwork('n*9*8')
#parse_tree[1]['n'] = 3
print parse_tree
etree = Eval_parsed.eval_parsed(parse_tree[0])
etree
#etree[0][1].is_integer()
#cluster_functions.flatten(parse_tree, 't')
# Out:
# ([['*', [0, 4]], [['*', [0, 2]], [['V', [0, 0]], 'n'], [['X', [2, 2]], 9]], [['X', [4, 4]], 8]], {'n': [0]})
# get_number got ['V', 'n', [0, 0], 'R.0.0']
# Eval_parsed Exception: string index out of range
# Traceback (most recent call last):
#   File "parsetrees/expr_parser/Eval_parsed.py", line 120, in eval_parsed
#     v1=get_number(ev1)
#   File "parsetrees/expr_parser/Eval_parsed.py", line 71, in get_number
#     return float(ev[0][1])
# IndexError: string index out of range
# get_number got None
# Eval_parsed Exception: object of type 'NoneType' has no len()
# Traceback (most recent call last):
#   File "parsetrees/expr_parser/Eval_parsed.py", line 120, in eval_parsed
#     v1=get_number(ev1)
#   File "parsetrees/expr_parser/Eval_parsed.py", line 66, in get_number
#     if len(ev)==4 and ev[0]=='X':
# TypeError: object of type 'NoneType' has no len()

# %%
#### Example of find_Hits
parse_tree = webwork_parser.parse_webwork('3*5+7')
etree_a = Eval_parsed.eval_parsed(parse_tree[0])
parse_tree_b = webwork_parser.parse_webwork('C(3,1)C(2,1)+7')
etree_b = Eval_parsed.eval_parsed(parse_tree_b[0])
p = {'attempt':'C(3,1)C(2,1)+7', 'answer':'3*5+7', 'att_tree':etree_b, 'ans_tree': etree_a}
print cluster_functions.find_matches(p)
print [int(i)+1 for i in cluster_functions.find_matches(p)[0][0].split('.')[1:]]
print parse_tree_b[0][1][1]
print tree_to_s_exp(parse_tree_b[0][1][1])
# Out:
# get_number got (3.0,)
# get_number got ['X', 3.0, [0, 0], 'R.0.0']
# get_number got (5.0,)
# get_number got ['X', 5.0, [2, 2], 'R.0.1']
# get_number got [['*', 15.0, [0, 2], 'R.0'], ['X', 3.0, [0, 0], 'R.0.0'], ['X', 5.0, [2, 2], 'R.0.1']]
# get_number got (7.0,)
# get_number got ['X', 7.0, [4, 4], 'R.1']
# get_number got (3.0,)
# get_number got ['X', 3.0, [2, 2], 'R.0.0.0']
# get_number got (1.0,)
# get_number got ['X', 1.0, [4, 4], 'R.0.0.1']
# get_number got [['C', 3, [0, 5], 'R.0.0'], ['X', 3.0, [2, 2], 'R.0.0.0'], ['X', 1.0, [4, 4], 'R.0.0.1']]
# get_number got (2.0,)
# get_number got ['X', 2.0, [8, 8], 'R.0.1.0']
# get_number got (1.0,)
# get_number got ['X', 1.0, [10, 10], 'R.0.1.1']
# get_number got [['C', 2, [6, 11], 'R.0.1'], ['X', 2.0, [8, 8], 'R.0.1.0'], ['X', 1.0, [10, 10], 'R.0.1.1']]
# get_number got [['*', 6.0, [0, 11], 'R.0'], [['C', 3, [0, 5], 'R.0.0'], ['X', 3.0, [2, 2], 'R.0.0.0'], ['X', 1.0, [4, 4], 'R.0.0.1']], [['C', 2, [6, 11], 'R.0.1'], ['X', 2.0, [8, 8], 'R.0.1.0'], ['X', 1.0, [10, 10], 'R.0.1.1']]]
# get_number got (7.0,)
# get_number got ['X', 7.0, [13, 13], 'R.1']
# [('R.0.0', 3.0, '3', 'C(3,1)'), ('R.1', 7.0, '7', '7')]
# [1, 1]
# [['C', [0, 5]], [['X', [2, 2]], 3], [['X', [4, 4]], 1]]
# (C (X 3) (X 1))

# %%
reload(cluster_functions)
def evaluate(ans, att):
    p = cluster_functions.make_params(ans, att)
    final_pairs = cluster_functions.find_matches()
    if len(final_pairs) == 1 and final_pairs[0][0] == 'R':
        return True
    return False
print evaluate('26^3-25^3', '24^3')
#cluster_functions.show_matching_group_w_variables('3*2+n', 'C(3,1)C(2,1)+n', {'n':[1,2,3,4,5]})
# Out:
# get_number got (26.0,)
# get_number got ['X', 26.0, [0, 1], 'R.0.0']
# get_number got (3.0,)
# get_number got ['X', 3.0, [3, 3], 'R.0.1']
# get_number got [['^', 17576.0, [0, 3], 'R.0'], ['X', 26.0, [0, 1], 'R.0.0'], ['X', 3.0, [3, 3], 'R.0.1']]
# get_number got (25.0,)
# get_number got ['X', 25.0, [5, 6], 'R.1.0']
# get_number got (3.0,)
# get_number got ['X', 3.0, [8, 8], 'R.1.1']
# get_number got [['^', 15625.0, [5, 8], 'R.1'], ['X', 25.0, [5, 6], 'R.1.0'], ['X', 3.0, [8, 8], 'R.1.1']]
# get_number got (24.0,)
# get_number got ['X', 24.0, [0, 1], 'R.0']
# get_number got (3.0,)
# get_number got ['X', 3.0, [3, 3], 'R.1']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-d548e3767ab9> in <module>()
#       6         return True
#       7     return False
# ----> 8 print evaluate('26^3-25^3', '24^3')
#       9 #cluster_functions.show_matching_group_w_variables('3*2+n', 'C(3,1)C(2,1)+n', {'n':[1,2,3,4,5]})
#
# <ipython-input-84-d548e3767ab9> in evaluate(ans, att)
#       2 def evaluate(ans, att):
#       3     p = cluster_functions.make_params(ans, att)
# ----> 4     final_pairs = cluster_functions.find_matches({})
#       5     if len(final_pairs) == 1 and final_pairs[0][0] == 'R':
#       6         return True
#
# /Users/janetzhai/Desktop/CSE103/Attempt_Analysis/clustering_code/cluster_functions.pyc in find_matches(params)
#      95 def find_matches(params):
#      96     """ return a list of hits """
# ---> 97     attempt=params['attempt']
#      98     attempt_tree=params['att_tree']
#      99     attempt_list=flatten(attempt_tree,'t')
#
# KeyError: 'attempt'

# %%
attempt=p['attempt']
attempt_tree=p['att_tree']
attempt_list=cluster_functions.flatten(attempt_tree,'t')
attempt_list
# Out:
# get_number got (3.0,)
# get_number got ['X', 3.0, [0, 0], 'R.0.0']
# get_number got (2.0,)
# get_number got ['X', 2.0, [2, 2], 'R.0.1']
# get_number got [['*', 6.0, [0, 2], 'R.0'], ['X', 3.0, [0, 0], 'R.0.0'], ['X', 2.0, [2, 2], 'R.0.1']]
# get_number got (4.0,)
# get_number got ['X', 4.0, [4, 4], 'R.1']
# get_number got (3.0,)
# get_number got ['X', 3.0, [2, 2], 'R.0.0']
# get_number got (1.0,)
# get_number got ['X', 1.0, [4, 4], 'R.0.1']
# get_number got [['C', 3, [0, 5], 'R.0'], ['X', 3.0, [2, 2], 'R.0.0'], ['X', 1.0, [4, 4], 'R.0.1']]
# get_number got (2.0,)
# get_number got ['X', 2.0, [8, 8], 'R.1.0']
# get_number got (1.0,)
# get_number got ['X', 1.0, [10, 10], 'R.1.1']
# get_number got [['C', 2, [6, 11], 'R.1'], ['X', 2.0, [8, 8], 'R.1.0'], ['X', 1.0, [10, 10], 'R.1.1']]
# [[1.0, 't', ['X', 1.0, [4, 4], 'R.0.1']],
#  [1.0, 't', ['X', 1.0, [10, 10], 'R.1.1']],
#  [2,
#   't',
#   [['C', 2, [6, 11], 'R.1'],
#    ['X', 2.0, [8, 8], 'R.1.0'],
#    ['X', 1.0, [10, 10], 'R.1.1']]],
#  [2.0, 't', ['X', 2.0, [8, 8], 'R.1.0']],
#  [3,
#   't',
#   [['C', 3, [0, 5], 'R.0'],
#    ['X', 3.0, [2, 2], 'R.0.0'],
#    ['X', 1.0, [4, 4], 'R.0.1']]],
#  [3.0, 't', ['X', 3.0, [2, 2], 'R.0.0']],
#  [6.0,
#   't',
#   [['*', 6.0, [0, 11], 'R'],
#    [['C', 3, [0, 5], 'R.0'],
#     ['X', 3.0, [2, 2], 'R.0.0'],
#     ['X', 1.0, [4, 4], 'R.0.1']],
#    [['C', 2, [6, 11], 'R.1'],
#     ['X', 2.0, [8, 8], 'R.1.0'],
#     ['X', 1.0, [10, 10], 'R.1.1']]]]]

# %%
answer=p['answer']
answer_tree=p['ans_tree']
answer_list=cluster_functions.flatten(answer_tree,'c')

combined_list=sorted(answer_list+attempt_list,key=lambda x: x[0])
combined_list
# Out:
# [[2.0, 'c', ['X', 2.0, [2, 2], 'R.1']],
#  [2.0, 't', ['X', 2.0, [2, 2], 'R.1']],
#  [3.0, 'c', ['X', 3.0, [0, 0], 'R.0']],
#  [3.0, 't', ['X', 3.0, [0, 0], 'R.0']],
#  [6.0,
#   'c',
#   [['*', 6.0, [0, 2], 'R'],
#    ['X', 3.0, [0, 0], 'R.0'],
#    ['X', 2.0, [2, 2], 'R.1']]],
#  [6.0,
#   't',
#   [['*', 6.0, [0, 2], 'R'],
#    ['X', 3.0, [0, 0], 'R.0'],
#    ['X', 2.0, [2, 2], 'R.1']]]]

# %%
Hits = cluster_functions.find_Hits(combined_list)
Hits
# Out:
# [([2.0, 'c', ['X', 2.0, [2, 2], 'R.1']],
#   [2.0, 't', ['X', 2.0, [2, 2], 'R.1']]),
#  ([3.0, 'c', ['X', 3.0, [0, 0], 'R.0']],
#   [3.0, 't', ['X', 3.0, [0, 0], 'R.0']]),
#  ([6.0,
#    'c',
#    [['*', 6.0, [0, 2], 'R'],
#     ['X', 3.0, [0, 0], 'R.0'],
#     ['X', 2.0, [2, 2], 'R.1']]],
#   [6.0,
#    't',
#    [['*', 6.0, [0, 2], 'R'],
#     ['X', 3.0, [0, 0], 'R.0'],
#     ['X', 2.0, [2, 2], 'R.1']]])]

# %%
#### Example of find_dominating_hits ####
cluster_functions.find_dominating_hits(Hits,answer,attempt)
# Out:
# [('R', 6.0, '3*2', 'C(3')]

# %%
### Count the number attempts and answer for each part ###
problem_count = defaultdict(int)
problem_part_answer = defaultdict(str)
for d in data:
    if d['answer']:
        problem_count[(d['problem_id'], d['part_id'])] += 1
        problem_part_answer[(d['problem_id'], d['part_id'])] = d['answer']
print len(data)
problem_part_answer
# Out:
# 17828
# defaultdict(str,
#             {(u'1', u'1'): u'B',
#              (u'2', u'1'): u'0.05/[sqrt(0.16/200)]',
#              (u'2', u'2'): u'Q(1.76777)',
#              (u'2',
#               u'3'): u'<pre style="text-align:left; padding-left:.2em">yes</pre>',
#              (u'2',
#               u'4'): u'<pre style="text-align:left; padding-left:.2em">no</pre>',
#              (u'5', u'1'): u'-0.02-2/[sqrt(25)]*2',
#              (u'5', u'2'): u'-0.03+2/[sqrt(25)]*2',
#              (u'5', u'3'): u'-1',
#              (u'5', u'4'): u'1',
#              (u'5', u'5'): u'1',
#              (u'6', u'1'): u'65',
#              (u'6',
#               u'2'): u'65*(0.5*[(30/65-0.5)/0.5]^2+0.25*[(20/65-0.25)/0.25]^2+0.25*[(15/65-0.25)/0.25]^2)',
#              (u'6',
#               u'3'): u'65*(1/3*[(30/65-1/3)/(1/3)]^2+1/3*[(20/65-1/3)/(1/3)]^2+1/3*[(15/65-1/3)/(1/3)]^2)',
#              (u'6',
#               u'4'): u'<pre style="text-align:left; padding-left:.2em">no</pre>',
#              (u'6',
#               u'5'): u'<pre style="text-align:left; padding-left:.2em">no</pre>',
#              (u'6',
#               u'6'): u'<pre style="text-align:left; padding-left:.2em">Yes</pre>',
#              (u'6',
#               u'7'): u'<pre style="text-align:left; padding-left:.2em">yes</pre>',
#              (u'6',
#               u'8'): u'<pre style="text-align:left; padding-left:.2em">yes</pre>',
#              (u'7', u'1'): u'-1',
#              (u'7', u'2'): u'-1',
#              (u'7', u'3'): u'1',
#              (u'7', u'4'): u'1',
#              (u'7', u'5'): u'1',
#              (u'8', u'1'): u'1',
#              (u'8', u'2'): u'0',
#              (u'9', u'1'): u'1000*100/x',
#              (u'9', u'2'): u'100*1000/n',
#              (u'9', u'3'): u'100*(1000/n)*(1-1000/n)',
#              (u'9', u'4'): u'1-2*0.025',
#              (u'9', u'5'): u'1.96*sqrt(100*(1000/n)*(1-1000/n))'})

# %%
webwork_parser.parse_webwork('(11!(11-6)')
# Out:
# ERROR:parsetrees.expr_parser.webwork_parser:||(11!(11-6)|| Unbalanced grouping operator in expression: (11!(11-6)
# ERROR:parsetrees.expr_parser.webwork_parser:Unbalanced grouping operator in expression: (11!(11-6)
# Traceback (most recent call last):
#   File "parsetrees/expr_parser/webwork_parser.py", line 332, in parse_webwork
#     parsed = parser.parse(expr,tracking=True, lexer=lexer.lexer)
#   File "/Library/Python/2.7/site-packages/ply/yacc.py", line 263, in parse
#     return self.parseopt(input,lexer,debug,tracking,tokenfunc)
#   File "/Library/Python/2.7/site-packages/ply/yacc.py", line 710, in parseopt
#     p.callable(pslice)
#   File "parsetrees/expr_parser/webwork_parser.py", line 228, in p_expression_unbalanced_group
#     raise WebworkParseException('Unbalanced grouping operator in expression: ' + t.lexer.lexdata)
# WebworkParseException: Unbalanced grouping operator in expression: (11!(11-6)
# Parse Error: Unbalanced Group Operator
# (11!(11-6)
# ^
# (None, {})

# %%
etree = Eval_parsed.eval_parsed(parse_tree[0])
# Out:
# eval_parsed, e=" [['!', [0, 11]], [['*', [1, 9]], [['!', [1, 3]], [['X', [1, 2]], 11]], [['-', [5, 8]], [['X', [5, 6]], 11], [['X', [8, 8]], 6]]]] "
# eval_parsed, e=" [['*', [1, 9]], [['!', [1, 3]], [['X', [1, 2]], 11]], [['-', [5, 8]], [['X', [5, 6]], 11], [['X', [8, 8]], 6]]] "
# eval_parsed, e=" [['!', [1, 3]], [['X', [1, 2]], 11]] "
# eval_parsed, e=" [['X', [1, 2]], 11] "
# eval_parsed, e=" 11 "
# 11.0
# 11.0
# eval_parsed, e=" [['-', [5, 8]], [['X', [5, 6]], 11], [['X', [8, 8]], 6]] "
# eval_parsed, e=" [['X', [5, 6]], 11] "
# eval_parsed, e=" 11 "
# 11.0
# eval_parsed, e=" [['X', [8, 8]], 6] "
# eval_parsed, e=" 6 "
# 6.0
# 199584000.0
# Eval_parsed Exception: 199584000.0 is too large to apply factorial
# Traceback (most recent call last):
#   File "parsetrees/expr_parser/Eval_parsed.py", line 97, in eval_parsed
#     raise Exception('%s is too large to apply factorial'%v)
# Exception: 199584000.0 is too large to apply factorial
